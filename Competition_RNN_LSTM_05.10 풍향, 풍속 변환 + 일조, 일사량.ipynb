# %%
import os
import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
# Out:
# In D:\Anaconda\envs\data_engeneering\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\Anaconda\envs\data_engeneering\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\Anaconda\envs\data_engeneering\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In D:\Anaconda\envs\data_engeneering\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\Anaconda\envs\data_engeneering\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\Anaconda\envs\data_engeneering\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\Anaconda\envs\data_engeneering\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\Anaconda\envs\data_engeneering\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
energy_floating = pd.read_csv('data/energy_floating_sunlight_wind.csv')
energy_warehouse = pd.read_csv('data/energy_warehouse_sunlight_wind.csv')
energy_dangjin = pd.read_csv('data/energy_dangjin_sunlight_wind.csv')
energy_ulsan = pd.read_csv('data/energy_ulsan_wind.csv')

# %%
model_path = 'model'
filename = []
filename.append(os.path.join(model_path, 'floating_wind_checkpoint.h5'))
filename.append(os.path.join(model_path, 'warehouse_wind_checkpoint.h5'))
filename.append(os.path.join(model_path, 'dangjin_wind_checkpoint.h5'))
filename.append(os.path.join(model_path, 'ulsan_wind_checkpoint.h5'))

# %%
def make_dataset(data, label, window_size=24):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

# %%
def root_mean_squared_error (y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
df = energy_floating.copy()
df.head(24)
# Out:
#                    time  dangjin_floating  capacity  time_generation  \
# 0   2018-03-02 00:00:00               0.0    1000.0            0.000
# 1   2018-03-02 01:00:00               0.0    1000.0            0.000
# 2   2018-03-02 02:00:00               0.0    1000.0            0.000
# 3   2018-03-02 03:00:00               0.0    1000.0            0.000
# 4   2018-03-02 04:00:00               0.0    1000.0            0.000
# 5   2018-03-02 05:00:00               0.0    1000.0            0.000
# 6   2018-03-02 06:00:00               0.0    1000.0            0.000
# 7   2018-03-02 07:00:00               0.0    1000.0            0.000
# 8   2018-03-02 08:00:00              11.0    1000.0            0.011
# 9   2018-03-02 09:00:00             134.0    1000.0            0.134
# 10  2018-03-02 10:00:00             363.0    1000.0            0.363
# 11  2018-03-02 11:00:00             563.0    1000.0            0.563
# 12  2018-03-02 12:00:00             691.0    1000.0            0.691
# 13  2018-03-02 13:00:00             592.0    1000.0            0.592
# 14  2018-03-02 14:00:00             619.0    1000.0            0.619
# 15  2018-03-02 15:00:00             708.0    1000.0            0.708
# 16  2018-03-02 16:00:00             537.0    1000.0            0.537
# 17  2018-03-02 17:00:00             351.0    1000.0            0.351
# 18  2018-03-02 18:00:00             138.0    1000.0            0.138
# 19  2018-03-02 19:00:00               9.0    1000.0            0.009
# 20  2018-03-02 20:00:00               0.0    1000.0            0.000
# 21  2018-03-02 21:00:00               0.0    1000.0            0.000
# 22  2018-03-02 22:00:00               0.0    1000.0            0.000
# 23  2018-03-02 23:00:00               0.0    1000.0            0.000
#
#     Temperature   Humidity     Cloud  일조(hr)  일사(MJ/m2)        Wind_X  \
# 0     -2.000000  55.000000  1.000000     0.0       0.00  6.120755e+00
# 1     -2.666667  55.000000  1.000000     0.0       0.00  5.799181e+00
# 2     -3.333333  55.000000  1.000000     0.0       0.00  5.470385e+00
# 3     -4.000000  55.000000  1.000000     0.0       0.00  5.134692e+00
# 4     -4.333333  56.666667  1.000000     0.0       0.00  4.812403e+00
# 5     -4.666667  58.333333  1.000000     0.0       0.00  4.478340e+00
# 6     -5.000000  60.000000  1.000000     0.0       0.00  4.133425e+00
# 7     -4.000000  58.333333  1.000000     0.0       0.00  3.402067e+00
# 8     -3.000000  56.666667  1.000000     0.5       0.20  2.668184e+00
# 9     -2.000000  55.000000  1.000000     1.0       0.92  1.931852e+00
# 10    -1.000000  51.666667  1.000000     1.0       1.63  1.137934e+00
# 11     0.000000  48.333333  1.000000     1.0       2.26  3.240484e-01
# 12     1.000000  45.000000  1.000000     1.0       2.69 -1.935375e-01
# 13     1.666667  46.666667  1.000000     1.0       2.89 -2.108313e-01
# 14     2.333333  48.333333  1.000000     1.0       2.85 -1.464456e-01
# 15     3.000000  50.000000  1.000000     1.0       2.55 -4.225031e-16
# 16     2.333333  51.666667  1.000000     1.0       2.00 -7.561558e-02
# 17     1.666667  53.333333  1.000000     1.0       1.26 -1.418382e-01
# 18     1.000000  55.000000  1.000000     1.0       0.48 -1.986041e-01
# 19     0.333333  60.000000  1.000000     0.0       0.02 -1.705314e+00
# 20    -0.333333  65.000000  1.000000     0.0       0.00 -1.166611e+00
# 21    -1.000000  70.000000  1.000000     0.0       0.00  5.993705e-01
# 22    -1.333333  73.333333  1.333333     0.0       0.00  4.726310e-01
# 23    -1.666667  76.666667  1.666667     0.0       0.00  2.723022e-01
#
#       Wind_Y
# 0  -2.725136
# 1  -2.461606
# 2  -2.210179
# 3  -1.971024
# 4  -1.688423
# 5  -1.426350
# 6  -1.185241
# 7  -0.954142
# 8  -0.731601
# 9  -0.517638
# 10 -1.124770
# 11 -1.155419
# 12 -0.776237
# 13 -1.282790
# 14 -1.794033
# 15 -2.300000
# 16 -2.165347
# 17 -2.028380
# 18 -1.889592
# 19 -0.576111
# 20  1.236535
# 21  1.483494
# 22  1.805842
# 23  2.115883

# %%
df.sort_index(ascending=False).reset_index(drop=True)

scaler = MinMaxScaler()
scale_cols = ['Temperature', 'Humidity', 'Wind_X', 'Wind_Y', 'Cloud']
df_scaled = scaler.fit_transform(df[scale_cols])
df_scaled = pd.DataFrame(df_scaled)
df_scaled['Generation'] = df['time_generation']
scale_cols.append('Generation')
df_scaled.columns = scale_cols

# %%
feature_cols = ['Temperature', 'Humidity', 'Wind_X', 'Wind_Y', 'Cloud']
label_cols = ['Generation']

window_size = 24
n = len(df_scaled)

train = df_scaled[:int(n*0.8)]
train.dropna(axis=0, inplace=True)
test = df_scaled[int(n*0.8):int(-(24*29))]
test.dropna(axis=0, inplace=True)
pred_input = df_scaled[int(-(24*29)):]
# Out:
# D:\Anaconda\envs\data_engeneering\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\Anaconda\envs\data_engeneering\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
train_feature, train_label = train[feature_cols], train[label_cols]
train_feature, train_label = make_dataset(train_feature, train_label, window_size)

x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2)

test_feature, test_label = test[feature_cols], test[label_cols]
test_feature, test_label = make_dataset(test_feature, test_label, window_size)

pred_feature, pred_label = pred_input[feature_cols], pred_input[label_cols]
pred_feature, pred_label = make_dataset(pred_feature, pred_label, window_size)

x_train.shape, x_valid.shape, test_feature.shape, pred_feature.shape
# Out:
# ((16796, 24, 5), (4199, 24, 5), (4541, 24, 5), (672, 24, 5))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, Dropout, Flatten, TimeDistributed
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import LSTM
from tensorflow.keras import backend as K

epoch = 100

# %%
model_0 = Sequential()
model_0.add(LSTM(24, 
               input_shape=(train_feature.shape[1], train_feature.shape[2]), 
               activation='relu', 
               kernel_regularizer=tf.keras.regularizers.l2(0.001),
               return_sequences=False)
          )

model_0.add(Dense(1, activation='relu'))
model_0.compile(loss='mean_squared_error', optimizer='adam')
model_0.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 24)                2880
# _________________________________________________________________
# dense (Dense)                (None, 1)                 25
# =================================================================
# Total params: 2,905
# Trainable params: 2,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10)
checkpoint = ModelCheckpoint(filename[0], monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
history_0 = model_0.fit(x_train, y_train, epochs=epoch,
                                      validation_data=(x_valid, y_valid), 
                                      callbacks=[early_stop, checkpoint])
# Out:
# Epoch 1/100
# 525/525 [==============================] - 4s 7ms/step - loss: 0.0326 - val_loss: 0.0130
#
# Epoch 00001: val_loss improved from inf to 0.01295, saving model to model\floating_wind_checkpoint.h5
# Epoch 2/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0128 - val_loss: 0.0118
#
# Epoch 00002: val_loss improved from 0.01295 to 0.01179, saving model to model\floating_wind_checkpoint.h5
# Epoch 3/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0118 - val_loss: 0.0114
#
# Epoch 00003: val_loss improved from 0.01179 to 0.01135, saving model to model\floating_wind_checkpoint.h5
# Epoch 4/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0110 - val_loss: 0.0106
#
# Epoch 00004: val_loss improved from 0.01135 to 0.01063, saving model to model\floating_wind_checkpoint.h5
# Epoch 5/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0104 - val_loss: 0.0102
#
# Epoch 00005: val_loss improved from 0.01063 to 0.01019, saving model to model\floating_wind_checkpoint.h5
# Epoch 6/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0105 - val_loss: 0.0099
#
# Epoch 00006: val_loss improved from 0.01019 to 0.00989, saving model to model\floating_wind_checkpoint.h5
# Epoch 7/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0101 - val_loss: 0.0102
#
# Epoch 00007: val_loss did not improve from 0.00989
# Epoch 8/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0099 - val_loss: 0.0097
#
# Epoch 00008: val_loss improved from 0.00989 to 0.00966, saving model to model\floating_wind_checkpoint.h5
# Epoch 9/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0097 - val_loss: 0.0101
#
# Epoch 00009: val_loss did not improve from 0.00966
# Epoch 10/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0096 - val_loss: 0.0093
#
# Epoch 00010: val_loss improved from 0.00966 to 0.00934, saving model to model\floating_wind_checkpoint.h5
# Epoch 11/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0093 - val_loss: 0.0096
#
# Epoch 00011: val_loss did not improve from 0.00934
# Epoch 12/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0095 - val_loss: 0.0092
#
# Epoch 00012: val_loss improved from 0.00934 to 0.00920, saving model to model\floating_wind_checkpoint.h5
# Epoch 13/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0088 - val_loss: 0.0088
#
# Epoch 00013: val_loss improved from 0.00920 to 0.00880, saving model to model\floating_wind_checkpoint.h5
# Epoch 14/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0089 - val_loss: 0.0092
#
# Epoch 00014: val_loss did not improve from 0.00880
# Epoch 15/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0089 - val_loss: 0.0092
#
# Epoch 00015: val_loss did not improve from 0.00880
# Epoch 16/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0091 - val_loss: 0.0089
#
# Epoch 00016: val_loss did not improve from 0.00880
# Epoch 17/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0089 - val_loss: 0.0086
#
# Epoch 00017: val_loss improved from 0.00880 to 0.00855, saving model to model\floating_wind_checkpoint.h5
# Epoch 18/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0088 - val_loss: 0.0087
#
# Epoch 00018: val_loss did not improve from 0.00855
# Epoch 19/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0084 - val_loss: 0.0100
#
# Epoch 00019: val_loss did not improve from 0.00855
# Epoch 20/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0085 - val_loss: 0.0086
#
# Epoch 00020: val_loss did not improve from 0.00855
# Epoch 21/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0088 - val_loss: 0.0085
#
# Epoch 00021: val_loss improved from 0.00855 to 0.00848, saving model to model\floating_wind_checkpoint.h5
# Epoch 22/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0087 - val_loss: 0.0085
#
# Epoch 00022: val_loss improved from 0.00848 to 0.00846, saving model to model\floating_wind_checkpoint.h5
# Epoch 23/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0087 - val_loss: 0.0084
#
# Epoch 00023: val_loss improved from 0.00846 to 0.00840, saving model to model\floating_wind_checkpoint.h5
# Epoch 24/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0085 - val_loss: 0.0082
#
# Epoch 00024: val_loss improved from 0.00840 to 0.00816, saving model to model\floating_wind_checkpoint.h5
# Epoch 25/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0085 - val_loss: 0.0081
#
# Epoch 00025: val_loss improved from 0.00816 to 0.00810, saving model to model\floating_wind_checkpoint.h5
# Epoch 26/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0083 - val_loss: 0.0082
#
# Epoch 00026: val_loss did not improve from 0.00810
# Epoch 27/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0081 - val_loss: 0.0080
#
# Epoch 00027: val_loss improved from 0.00810 to 0.00797, saving model to model\floating_wind_checkpoint.h5
# Epoch 28/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0082 - val_loss: 0.0085
#
# Epoch 00028: val_loss did not improve from 0.00797
# Epoch 29/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0083 - val_loss: 0.0083
#
# Epoch 00029: val_loss did not improve from 0.00797
# Epoch 30/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0081 - val_loss: 0.0085
#
# Epoch 00030: val_loss did not improve from 0.00797
# Epoch 31/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0079 - val_loss: 0.0081
#
# Epoch 00031: val_loss did not improve from 0.00797
# Epoch 32/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0080 - val_loss: 0.0080
#
# Epoch 00032: val_loss did not improve from 0.00797
# Epoch 33/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0079 - val_loss: 0.0082
#
# Epoch 00033: val_loss did not improve from 0.00797
# Epoch 34/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0080 - val_loss: 0.0078
#
# Epoch 00034: val_loss improved from 0.00797 to 0.00778, saving model to model\floating_wind_checkpoint.h5
# Epoch 35/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0082 - val_loss: 0.0080
#
# Epoch 00035: val_loss did not improve from 0.00778
# Epoch 36/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0080 - val_loss: 0.0079
#
# Epoch 00036: val_loss did not improve from 0.00778
# Epoch 37/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0078 - val_loss: 0.0078
#
# Epoch 00037: val_loss did not improve from 0.00778
# Epoch 38/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0079 - val_loss: 0.0086
#
# Epoch 00038: val_loss did not improve from 0.00778
# Epoch 39/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0080 - val_loss: 0.0078
#
# Epoch 00039: val_loss did not improve from 0.00778
# Epoch 40/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0075 - val_loss: 0.0078
#
# Epoch 00040: val_loss improved from 0.00778 to 0.00777, saving model to model\floating_wind_checkpoint.h5
# Epoch 41/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0077 - val_loss: 0.0083
#
# Epoch 00041: val_loss did not improve from 0.00777
# Epoch 42/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0076 - val_loss: 0.0080
#
# Epoch 00042: val_loss did not improve from 0.00777
# Epoch 43/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0081 - val_loss: 0.0075
#
# Epoch 00043: val_loss improved from 0.00777 to 0.00751, saving model to model\floating_wind_checkpoint.h5
# Epoch 44/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0077 - val_loss: 0.0081
#
# Epoch 00044: val_loss did not improve from 0.00751
# Epoch 45/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0079 - val_loss: 0.0078
#
# Epoch 00045: val_loss did not improve from 0.00751
# Epoch 46/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0077 - val_loss: 0.0076
#
# Epoch 00046: val_loss did not improve from 0.00751
# Epoch 47/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0078 - val_loss: 0.0078
#
# Epoch 00047: val_loss did not improve from 0.00751
# Epoch 48/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0077 - val_loss: 0.0076
#
# Epoch 00048: val_loss did not improve from 0.00751
# Epoch 49/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0077 - val_loss: 0.0084
#
# Epoch 00049: val_loss did not improve from 0.00751
# Epoch 50/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0078 - val_loss: 0.0076
#
# Epoch 00050: val_loss did not improve from 0.00751
# Epoch 51/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0074 - val_loss: 0.0076
#
# Epoch 00051: val_loss did not improve from 0.00751
# Epoch 52/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0074 - val_loss: 0.0081
#
# Epoch 00052: val_loss did not improve from 0.00751
# Epoch 53/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0076 - val_loss: 0.0079
#
# Epoch 00053: val_loss did not improve from 0.00751

# %%
floating_pred = model_0.predict(pred_feature)

# %%
df = energy_warehouse.copy()
df.head(24)
# Out:
#                    time  dangjin_warehouse  capacity  time_generation  \
# 0   2018-03-02 00:00:00                0.0     700.0         0.000000
# 1   2018-03-02 01:00:00                0.0     700.0         0.000000
# 2   2018-03-02 02:00:00                0.0     700.0         0.000000
# 3   2018-03-02 03:00:00                0.0     700.0         0.000000
# 4   2018-03-02 04:00:00                0.0     700.0         0.000000
# 5   2018-03-02 05:00:00                0.0     700.0         0.000000
# 6   2018-03-02 06:00:00                0.0     700.0         0.000000
# 7   2018-03-02 07:00:00                0.0     700.0         0.000000
# 8   2018-03-02 08:00:00                9.0     700.0         0.012857
# 9   2018-03-02 09:00:00               93.0     700.0         0.132857
# 10  2018-03-02 10:00:00              247.0     700.0         0.352857
# 11  2018-03-02 11:00:00              388.0     700.0         0.554286
# 12  2018-03-02 12:00:00              479.0     700.0         0.684286
# 13  2018-03-02 13:00:00              524.0     700.0         0.748571
# 14  2018-03-02 14:00:00              539.0     700.0         0.770000
# 15  2018-03-02 15:00:00              504.0     700.0         0.720000
# 16  2018-03-02 16:00:00              426.0     700.0         0.608571
# 17  2018-03-02 17:00:00              288.0     700.0         0.411429
# 18  2018-03-02 18:00:00               81.0     700.0         0.115714
# 19  2018-03-02 19:00:00                1.0     700.0         0.001429
# 20  2018-03-02 20:00:00                0.0     700.0         0.000000
# 21  2018-03-02 21:00:00                0.0     700.0         0.000000
# 22  2018-03-02 22:00:00                0.0     700.0         0.000000
# 23  2018-03-02 23:00:00                0.0     700.0         0.000000
#
#     Temperature   Humidity     Cloud  일조(hr)  일사(MJ/m2)        Wind_X  \
# 0     -2.000000  55.000000  1.000000     0.0       0.00  6.120755e+00
# 1     -2.666667  55.000000  1.000000     0.0       0.00  5.799181e+00
# 2     -3.333333  55.000000  1.000000     0.0       0.00  5.470385e+00
# 3     -4.000000  55.000000  1.000000     0.0       0.00  5.134692e+00
# 4     -4.333333  56.666667  1.000000     0.0       0.00  4.812403e+00
# 5     -4.666667  58.333333  1.000000     0.0       0.00  4.478340e+00
# 6     -5.000000  60.000000  1.000000     0.0       0.00  4.133425e+00
# 7     -4.000000  58.333333  1.000000     0.0       0.00  3.402067e+00
# 8     -3.000000  56.666667  1.000000     0.5       0.20  2.668184e+00
# 9     -2.000000  55.000000  1.000000     1.0       0.92  1.931852e+00
# 10    -1.000000  51.666667  1.000000     1.0       1.63  1.137934e+00
# 11     0.000000  48.333333  1.000000     1.0       2.26  3.240484e-01
# 12     1.000000  45.000000  1.000000     1.0       2.69 -1.935375e-01
# 13     1.666667  46.666667  1.000000     1.0       2.89 -2.108313e-01
# 14     2.333333  48.333333  1.000000     1.0       2.85 -1.464456e-01
# 15     3.000000  50.000000  1.000000     1.0       2.55 -4.225031e-16
# 16     2.333333  51.666667  1.000000     1.0       2.00 -7.561558e-02
# 17     1.666667  53.333333  1.000000     1.0       1.26 -1.418382e-01
# 18     1.000000  55.000000  1.000000     1.0       0.48 -1.986041e-01
# 19     0.333333  60.000000  1.000000     0.0       0.02 -1.705314e+00
# 20    -0.333333  65.000000  1.000000     0.0       0.00 -1.166611e+00
# 21    -1.000000  70.000000  1.000000     0.0       0.00  5.993705e-01
# 22    -1.333333  73.333333  1.333333     0.0       0.00  4.726310e-01
# 23    -1.666667  76.666667  1.666667     0.0       0.00  2.723022e-01
#
#       Wind_Y
# 0  -2.725136
# 1  -2.461606
# 2  -2.210179
# 3  -1.971024
# 4  -1.688423
# 5  -1.426350
# 6  -1.185241
# 7  -0.954142
# 8  -0.731601
# 9  -0.517638
# 10 -1.124770
# 11 -1.155419
# 12 -0.776237
# 13 -1.282790
# 14 -1.794033
# 15 -2.300000
# 16 -2.165347
# 17 -2.028380
# 18 -1.889592
# 19 -0.576111
# 20  1.236535
# 21  1.483494
# 22  1.805842
# 23  2.115883

# %%
df.sort_index(ascending=False).reset_index(drop=True)

scaler = MinMaxScaler()
scale_cols = ['Temperature', 'Humidity', 'Wind_X', 'Wind_Y', 'Cloud']
df_scaled = scaler.fit_transform(df[scale_cols])
df_scaled = pd.DataFrame(df_scaled)
df_scaled['Generation'] = df['time_generation']
scale_cols.append('Generation')
df_scaled.columns = scale_cols

# %%
feature_cols = ['Temperature', 'Humidity', 'Wind_X', 'Wind_Y', 'Cloud']
label_cols = ['Generation']

window_size = 24
n = len(df_scaled)

train = df_scaled[:int(n*0.8)]
train.dropna(axis=0, inplace=True)
test = df_scaled[int(n*0.8):int(-(24*29))]
test.dropna(axis=0, inplace=True)
pred_input = df_scaled[int(-(24*29)):]
# Out:
# D:\Anaconda\envs\data_engeneering\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\Anaconda\envs\data_engeneering\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
train_feature, train_label = train[feature_cols], train[label_cols]
train_feature, train_label = make_dataset(train_feature, train_label, window_size)

x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2)

test_feature, test_label = test[feature_cols], test[label_cols]
test_feature, test_label = make_dataset(test_feature, test_label, window_size)

pred_feature, pred_label = pred_input[feature_cols], pred_input[label_cols]
pred_feature, pred_label = make_dataset(pred_feature, pred_label, window_size)

x_train.shape, x_valid.shape, test_feature.shape, pred_feature.shape
# Out:
# ((16776, 24, 5), (4195, 24, 5), (4541, 24, 5), (672, 24, 5))

# %%
model_1 = Sequential()
model_1.add(LSTM(24, 
               input_shape=(train_feature.shape[1], train_feature.shape[2]), 
               activation='relu', 
               kernel_regularizer=tf.keras.regularizers.l2(0.001),
               return_sequences=False)
          )

# model.add(Dense(1))
# model.add(LeakyReLU(alpha=0.05))
model_1.add(Dense(1, activation='relu'))
model_1.compile(loss='mean_squared_error', optimizer='adam')
model_1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 24)                2880
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 2,905
# Trainable params: 2,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10)
checkpoint = ModelCheckpoint(filename[1], monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
history_1 = model_1.fit(x_train, y_train, epochs=epoch,
                                      validation_data=(x_valid, y_valid), 
                                      callbacks=[early_stop, checkpoint])
# Out:
# Epoch 1/100
# 525/525 [==============================] - 4s 6ms/step - loss: 0.0438 - val_loss: 0.0163
#
# Epoch 00001: val_loss improved from inf to 0.01631, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 2/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0159 - val_loss: 0.0144
#
# Epoch 00002: val_loss improved from 0.01631 to 0.01444, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 3/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0131 - val_loss: 0.0134
#
# Epoch 00003: val_loss improved from 0.01444 to 0.01343, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 4/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0125 - val_loss: 0.0125
#
# Epoch 00004: val_loss improved from 0.01343 to 0.01245, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 5/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0122 - val_loss: 0.0120
#
# Epoch 00005: val_loss improved from 0.01245 to 0.01200, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 6/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0114 - val_loss: 0.0117
#
# Epoch 00006: val_loss improved from 0.01200 to 0.01168, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 7/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0113 - val_loss: 0.0115
#
# Epoch 00007: val_loss improved from 0.01168 to 0.01148, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 8/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0112 - val_loss: 0.0110
#
# Epoch 00008: val_loss improved from 0.01148 to 0.01100, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 9/100
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0108 - val_loss: 0.0106
#
# Epoch 00009: val_loss improved from 0.01100 to 0.01059, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 10/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0101 - val_loss: 0.0107
#
# Epoch 00010: val_loss did not improve from 0.01059
# Epoch 11/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0107 - val_loss: 0.0105
#
# Epoch 00011: val_loss improved from 0.01059 to 0.01049, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 12/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0104 - val_loss: 0.0108
#
# Epoch 00012: val_loss did not improve from 0.01049
# Epoch 13/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0102 - val_loss: 0.0100
#
# Epoch 00013: val_loss improved from 0.01049 to 0.01004, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 14/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0100 - val_loss: 0.0110
#
# Epoch 00014: val_loss did not improve from 0.01004
# Epoch 15/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0094 - val_loss: 0.0103
#
# Epoch 00015: val_loss did not improve from 0.01004
# Epoch 16/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0096 - val_loss: 0.0101
#
# Epoch 00016: val_loss did not improve from 0.01004
# Epoch 17/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0092 - val_loss: 0.0095
#
# Epoch 00017: val_loss improved from 0.01004 to 0.00947, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 18/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0096 - val_loss: 0.0101
#
# Epoch 00018: val_loss did not improve from 0.00947
# Epoch 19/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0096 - val_loss: 0.0095
#
# Epoch 00019: val_loss improved from 0.00947 to 0.00945, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 20/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0090 - val_loss: 0.0094
#
# Epoch 00020: val_loss improved from 0.00945 to 0.00935, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 21/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0094 - val_loss: 0.0099
#
# Epoch 00021: val_loss did not improve from 0.00935
# Epoch 22/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0095 - val_loss: 0.0096
#
# Epoch 00022: val_loss did not improve from 0.00935
# Epoch 23/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0094 - val_loss: 0.0110
#
# Epoch 00023: val_loss did not improve from 0.00935
# Epoch 24/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0093 - val_loss: 0.0094
#
# Epoch 00024: val_loss did not improve from 0.00935
# Epoch 25/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0094 - val_loss: 0.0094
#
# Epoch 00025: val_loss did not improve from 0.00935
# Epoch 26/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0091 - val_loss: 0.0098
#
# Epoch 00026: val_loss did not improve from 0.00935
# Epoch 27/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0090 - val_loss: 0.0093
#
# Epoch 00027: val_loss improved from 0.00935 to 0.00926, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 28/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0094 - val_loss: 0.0097
#
# Epoch 00028: val_loss did not improve from 0.00926
# Epoch 29/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0095 - val_loss: 0.0094
#
# Epoch 00029: val_loss did not improve from 0.00926
# Epoch 30/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0092 - val_loss: 0.0094
#
# Epoch 00030: val_loss did not improve from 0.00926
# Epoch 31/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0092 - val_loss: 0.0095
#
# Epoch 00031: val_loss did not improve from 0.00926
# Epoch 32/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0088 - val_loss: 0.0097
#
# Epoch 00032: val_loss did not improve from 0.00926
# Epoch 33/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0092 - val_loss: 0.0096
#
# Epoch 00033: val_loss did not improve from 0.00926
# Epoch 34/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0089 - val_loss: 0.0091
#
# Epoch 00034: val_loss improved from 0.00926 to 0.00911, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 35/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0091 - val_loss: 0.0092
#
# Epoch 00035: val_loss did not improve from 0.00911
# Epoch 36/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0090 - val_loss: 0.0091
#
# Epoch 00036: val_loss improved from 0.00911 to 0.00906, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 37/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0085 - val_loss: 0.0089
#
# Epoch 00037: val_loss improved from 0.00906 to 0.00885, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 38/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0088 - val_loss: 0.0091
#
# Epoch 00038: val_loss did not improve from 0.00885
# Epoch 39/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0087 - val_loss: 0.0090
#
# Epoch 00039: val_loss did not improve from 0.00885
# Epoch 40/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0089 - val_loss: 0.0088
#
# Epoch 00040: val_loss improved from 0.00885 to 0.00880, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 41/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0085 - val_loss: 0.0092
#
# Epoch 00041: val_loss did not improve from 0.00880
# Epoch 42/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0086 - val_loss: 0.0091
#
# Epoch 00042: val_loss did not improve from 0.00880
# Epoch 43/100
# 525/525 [==============================] - 2s 5ms/step - loss: 0.0085 - val_loss: 0.0088
#
# Epoch 00043: val_loss improved from 0.00880 to 0.00878, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 44/100
# 525/525 [==============================] - 2s 5ms/step - loss: 0.0086 - val_loss: 0.0087
#
# Epoch 00044: val_loss improved from 0.00878 to 0.00871, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 45/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0084 - val_loss: 0.0088
#
# Epoch 00045: val_loss did not improve from 0.00871
# Epoch 46/100
# 525/525 [==============================] - 2s 5ms/step - loss: 0.0087 - val_loss: 0.0089
# Epoch 00046: val_loss did not improve from 0.00871
# Epoch 47/100
# 525/525 [==============================] - 2s 5ms/step - loss: 0.0085 - val_loss: 0.0089
#
# Epoch 00047: val_loss did not improve from 0.00871
# Epoch 48/100
# 525/525 [==============================] - 2s 5ms/step - loss: 0.0085 - val_loss: 0.0089
#
# Epoch 00048: val_loss did not improve from 0.00871
# Epoch 49/100
# 525/525 [==============================] - 2s 5ms/step - loss: 0.0085 - val_loss: 0.0091
#
# Epoch 00049: val_loss did not improve from 0.00871
# Epoch 50/100
# 525/525 [==============================] - 2s 5ms/step - loss: 0.0086 - val_loss: 0.0087
#
# Epoch 00050: val_loss did not improve from 0.00871
# Epoch 51/100
# 525/525 [==============================] - 2s 5ms/step - loss: 0.0085 - val_loss: 0.0090
#
# Epoch 00051: val_loss did not improve from 0.00871
# Epoch 52/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0086 - val_loss: 0.0086
#
# Epoch 00052: val_loss improved from 0.00871 to 0.00858, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 53/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0085 - val_loss: 0.0085
#
# Epoch 00053: val_loss improved from 0.00858 to 0.00850, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 54/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0083 - val_loss: 0.0103
#
# Epoch 00054: val_loss did not improve from 0.00850
# Epoch 55/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0084 - val_loss: 0.0085
#
# Epoch 00055: val_loss did not improve from 0.00850
# Epoch 56/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0086 - val_loss: 0.0087
#
# Epoch 00056: val_loss did not improve from 0.00850
# Epoch 57/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0085 - val_loss: 0.0087
#
# Epoch 00057: val_loss did not improve from 0.00850
# Epoch 58/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0081 - val_loss: 0.0086
#
# Epoch 00058: val_loss did not improve from 0.00850
# Epoch 59/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0080 - val_loss: 0.0085
#
# Epoch 00059: val_loss improved from 0.00850 to 0.00848, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 60/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0082 - val_loss: 0.0090
#
# Epoch 00060: val_loss did not improve from 0.00848
# Epoch 61/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0083 - val_loss: 0.0091
#
# Epoch 00061: val_loss did not improve from 0.00848
# Epoch 62/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0083 - val_loss: 0.0086
#
# Epoch 00062: val_loss did not improve from 0.00848
# Epoch 63/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0083 - val_loss: 0.0090
#
# Epoch 00063: val_loss did not improve from 0.00848
# Epoch 64/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0079 - val_loss: 0.0085
#
# Epoch 00064: val_loss improved from 0.00848 to 0.00847, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 65/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0080 - val_loss: 0.0088
#
# Epoch 00065: val_loss did not improve from 0.00847
# Epoch 66/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0081 - val_loss: 0.0087
#
# Epoch 00066: val_loss did not improve from 0.00847
# Epoch 67/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0082 - val_loss: 0.0088
#
# Epoch 00067: val_loss did not improve from 0.00847
# Epoch 68/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0082 - val_loss: 0.0088
#
# Epoch 00068: val_loss did not improve from 0.00847
# Epoch 69/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0082 - val_loss: 0.0085
#
# Epoch 00069: val_loss improved from 0.00847 to 0.00846, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 70/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0080 - val_loss: 0.0085
#
# Epoch 00070: val_loss did not improve from 0.00846
# Epoch 71/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0083 - val_loss: 0.0092
#
# Epoch 00071: val_loss did not improve from 0.00846
# Epoch 72/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0083 - val_loss: 0.0084
#
# Epoch 00072: val_loss improved from 0.00846 to 0.00836, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 73/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0081 - val_loss: 0.0088
#
# Epoch 00073: val_loss did not improve from 0.00836
# Epoch 74/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0081 - val_loss: 0.0085
#
# Epoch 00074: val_loss did not improve from 0.00836
# Epoch 75/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0080 - val_loss: 0.0085
#
# Epoch 00075: val_loss did not improve from 0.00836
# Epoch 76/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0081 - val_loss: 0.0088
#
# Epoch 00076: val_loss did not improve from 0.00836
# Epoch 77/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0079 - val_loss: 0.0084
#
# Epoch 00077: val_loss improved from 0.00836 to 0.00835, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 78/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0082 - val_loss: 0.0082
#
# Epoch 00078: val_loss improved from 0.00835 to 0.00818, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 79/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0079 - val_loss: 0.0082
#
# Epoch 00079: val_loss did not improve from 0.00818
# Epoch 80/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0077 - val_loss: 0.0089
#
# Epoch 00080: val_loss did not improve from 0.00818
# Epoch 81/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0080 - val_loss: 0.0086
#
# Epoch 00081: val_loss did not improve from 0.00818
# Epoch 82/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0081 - val_loss: 0.0081
#
# Epoch 00082: val_loss improved from 0.00818 to 0.00815, saving model to model\warehouse_wind_checkpoint.h5
# Epoch 83/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0081 - val_loss: 0.0088
#
# Epoch 00083: val_loss did not improve from 0.00815
# Epoch 84/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0079 - val_loss: 0.0083
#
# Epoch 00084: val_loss did not improve from 0.00815
# Epoch 85/100
# 525/525 [==============================] - 2s 5ms/step - loss: 0.0076 - val_loss: 0.0087
#
# Epoch 00085: val_loss did not improve from 0.00815
# Epoch 86/100
# 525/525 [==============================] - 2s 5ms/step - loss: 0.0079 - val_loss: 0.0083
#
# Epoch 00086: val_loss did not improve from 0.00815
# Epoch 87/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0082 - val_loss: 0.0083
#
# Epoch 00087: val_loss did not improve from 0.00815
# Epoch 88/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0077 - val_loss: 0.0083
#
# Epoch 00088: val_loss did not improve from 0.00815
# Epoch 89/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0076 - val_loss: 0.0082
#
# Epoch 00089: val_loss did not improve from 0.00815
# Epoch 90/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0077 - val_loss: 0.0084
#
# Epoch 00090: val_loss did not improve from 0.00815
# Epoch 91/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0080 - val_loss: 0.0086
#
# Epoch 00091: val_loss did not improve from 0.00815
# Epoch 92/100
# 525/525 [==============================] - 3s 5ms/step - loss: 0.0078 - val_loss: 0.0084
#
# Epoch 00092: val_loss did not improve from 0.00815

# %%
warehouse_pred = model_1.predict(pred_feature)

# %%
df = energy_dangjin.copy()
df.head(24)
# Out:
#                    time  dangjin  capacity  time_generation  Temperature  \
# 0   2018-03-02 00:00:00      0.0    1000.0            0.000    -2.000000
# 1   2018-03-02 01:00:00      0.0    1000.0            0.000    -2.666667
# 2   2018-03-02 02:00:00      0.0    1000.0            0.000    -3.333333
# 3   2018-03-02 03:00:00      0.0    1000.0            0.000    -4.000000
# 4   2018-03-02 04:00:00      0.0    1000.0            0.000    -4.333333
# 5   2018-03-02 05:00:00      0.0    1000.0            0.000    -4.666667
# 6   2018-03-02 06:00:00      0.0    1000.0            0.000    -5.000000
# 7   2018-03-02 07:00:00      0.0    1000.0            0.000    -4.000000
# 8   2018-03-02 08:00:00      4.0    1000.0            0.004    -3.000000
# 9   2018-03-02 09:00:00    154.0    1000.0            0.154    -2.000000
# 10  2018-03-02 10:00:00    367.0    1000.0            0.367    -1.000000
# 11  2018-03-02 11:00:00    539.0    1000.0            0.539     0.000000
# 12  2018-03-02 12:00:00    644.0    1000.0            0.644     1.000000
# 13  2018-03-02 13:00:00    709.0    1000.0            0.709     1.666667
# 14  2018-03-02 14:00:00    739.0    1000.0            0.739     2.333333
# 15  2018-03-02 15:00:00    693.0    1000.0            0.693     3.000000
# 16  2018-03-02 16:00:00    583.0    1000.0            0.583     2.333333
# 17  2018-03-02 17:00:00    409.0    1000.0            0.409     1.666667
# 18  2018-03-02 18:00:00    125.0    1000.0            0.125     1.000000
# 19  2018-03-02 19:00:00      0.0    1000.0            0.000     0.333333
# 20  2018-03-02 20:00:00      0.0    1000.0            0.000    -0.333333
# 21  2018-03-02 21:00:00      0.0    1000.0            0.000    -1.000000
# 22  2018-03-02 22:00:00      0.0    1000.0            0.000    -1.333333
# 23  2018-03-02 23:00:00      0.0    1000.0            0.000    -1.666667
#
#      Humidity     Cloud  일조(hr)  일사(MJ/m2)        Wind_X    Wind_Y
# 0   55.000000  1.000000     0.0       0.00  6.120755e+00 -2.725136
# 1   55.000000  1.000000     0.0       0.00  5.799181e+00 -2.461606
# 2   55.000000  1.000000     0.0       0.00  5.470385e+00 -2.210179
# 3   55.000000  1.000000     0.0       0.00  5.134692e+00 -1.971024
# 4   56.666667  1.000000     0.0       0.00  4.812403e+00 -1.688423
# 5   58.333333  1.000000     0.0       0.00  4.478340e+00 -1.426350
# 6   60.000000  1.000000     0.0       0.00  4.133425e+00 -1.185241
# 7   58.333333  1.000000     0.0       0.00  3.402067e+00 -0.954142
# 8   56.666667  1.000000     0.5       0.20  2.668184e+00 -0.731601
# 9   55.000000  1.000000     1.0       0.92  1.931852e+00 -0.517638
# 10  51.666667  1.000000     1.0       1.63  1.137934e+00 -1.124770
# 11  48.333333  1.000000     1.0       2.26  3.240484e-01 -1.155419
# 12  45.000000  1.000000     1.0       2.69 -1.935375e-01 -0.776237
# 13  46.666667  1.000000     1.0       2.89 -2.108313e-01 -1.282790
# 14  48.333333  1.000000     1.0       2.85 -1.464456e-01 -1.794033
# 15  50.000000  1.000000     1.0       2.55 -4.225031e-16 -2.300000
# 16  51.666667  1.000000     1.0       2.00 -7.561558e-02 -2.165347
# 17  53.333333  1.000000     1.0       1.26 -1.418382e-01 -2.028380
# 18  55.000000  1.000000     1.0       0.48 -1.986041e-01 -1.889592
# 19  60.000000  1.000000     0.0       0.02 -1.705314e+00 -0.576111
# 20  65.000000  1.000000     0.0       0.00 -1.166611e+00  1.236535
# 21  70.000000  1.000000     0.0       0.00  5.993705e-01  1.483494
# 22  73.333333  1.333333     0.0       0.00  4.726310e-01  1.805842
# 23  76.666667  1.666667     0.0       0.00  2.723022e-01  2.115883

# %%
df.sort_index(ascending=False).reset_index(drop=True)

scaler = MinMaxScaler()
scale_cols = ['Temperature', 'Humidity', 'Wind_X', 'Wind_Y', 'Cloud', '일조(hr)', '일사(MJ/m2)']
df_scaled = scaler.fit_transform(df[scale_cols])
df_scaled = pd.DataFrame(df_scaled)
df_scaled['Generation'] = df['time_generation']
scale_cols.append('Generation')
df_scaled.columns = scale_cols

# %%
feature_cols = ['Temperature', 'Humidity', 'Wind_X', 'Wind_Y', 'Cloud', '일조(hr)', '일사(MJ/m2)']
label_cols = ['Generation']

window_size = 24
n = len(df_scaled)

train = df_scaled[:int(n*0.8)]
train.dropna(axis=0, inplace=True)
test = df_scaled[int(n*0.8):int(-(24*29))]
test.dropna(axis=0, inplace=True)
pred_input = df_scaled[int(-(24*29)):]
# Out:
# D:\Anaconda\envs\data_engeneering\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\Anaconda\envs\data_engeneering\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_scaled[12:25]
# Out:
#     Temperature  Humidity    Wind_X    Wind_Y     Cloud  일조(hr)  일사(MJ/m2)  \
# 12     0.306122  0.352941  0.562238  0.439099  0.000000     1.0   0.554639
# 13     0.319728  0.372549  0.561883  0.428387  0.000000     1.0   0.595876
# 14     0.333333  0.392157  0.563205  0.417575  0.000000     1.0   0.587629
# 15     0.346939  0.411765  0.566210  0.406875  0.000000     1.0   0.525773
# 16     0.333333  0.431373  0.564658  0.409723  0.000000     1.0   0.412371
# 17     0.319728  0.450980  0.563299  0.412619  0.000000     1.0   0.259794
# 18     0.306122  0.470588  0.562134  0.415554  0.000000     1.0   0.098969
# 19     0.292517  0.529412  0.531211  0.443331  0.000000     0.0   0.004124
# 20     0.278912  0.588235  0.542267  0.481664  0.000000     0.0   0.000000
# 21     0.265306  0.647059  0.578511  0.486887  0.000000     0.0   0.000000
# 22     0.258503  0.686275  0.575910  0.493704  0.111111     0.0   0.000000
# 23     0.251701  0.725490  0.571799  0.500260  0.222222     0.0   0.000000
# 24     0.244898  0.764706  0.566210  0.506269  0.333333     0.0   0.000000
#
#     Generation
# 12       0.644
# 13       0.709
# 14       0.739
# 15       0.693
# 16       0.583
# 17       0.409
# 18       0.125
# 19       0.000
# 20       0.000
# 21       0.000
# 22       0.000
# 23       0.000
# 24       0.000

# %%
train_feature, train_label = train[feature_cols], train[label_cols]
train_feature, train_label = make_dataset(train_feature, train_label, window_size)

x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2)

test_feature, test_label = test[feature_cols], test[label_cols]
test_feature, test_label = make_dataset(test_feature, test_label, window_size)

pred_feature, pred_label = pred_input[feature_cols], pred_input[label_cols]
pred_feature, pred_label = make_dataset(pred_feature, pred_label, window_size)

x_train.shape, x_valid.shape, test_feature.shape, pred_feature.shape
# Out:
# ((16815, 24, 7), (4204, 24, 7), (4541, 24, 7), (672, 24, 7))

# %%
model_2 = Sequential()
model_2.add(LSTM(24, 
               input_shape=(train_feature.shape[1], train_feature.shape[2]), 
               activation='relu', 
               kernel_regularizer=tf.keras.regularizers.l2(0.001),
               return_sequences=False)
          )

# model.add(Dense(1))
# model.add(LeakyReLU(alpha=0.05))
model_2.add(Dense(1, activation='relu'))
model_2.compile(loss='mean_squared_error', optimizer='adam')
model_2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 24)                3072
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 3,097
# Trainable params: 3,097
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10)
checkpoint = ModelCheckpoint(filename[2], monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
history_2 = model_2.fit(x_train, y_train, epochs=epoch,
                                      validation_data=(x_valid, y_valid), 
                                      callbacks=[early_stop, checkpoint])
# Out:
# Epoch 1/100
# 526/526 [==============================] - 4s 6ms/step - loss: 0.0266 - val_loss: 0.0123
#
# Epoch 00001: val_loss improved from inf to 0.01230, saving model to model\dangjin_wind_checkpoint.h5
# Epoch 2/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0104 - val_loss: 0.0086
#
# Epoch 00002: val_loss improved from 0.01230 to 0.00865, saving model to model\dangjin_wind_checkpoint.h5
# Epoch 3/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0085 - val_loss: 0.0076
#
# Epoch 00003: val_loss improved from 0.00865 to 0.00760, saving model to model\dangjin_wind_checkpoint.h5
# Epoch 4/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0075 - val_loss: 0.0069
#
# Epoch 00004: val_loss improved from 0.00760 to 0.00688, saving model to model\dangjin_wind_checkpoint.h5
# Epoch 5/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0070 - val_loss: 0.0071
#
# Epoch 00005: val_loss did not improve from 0.00688
# Epoch 6/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0065 - val_loss: 0.0065
#
# Epoch 00006: val_loss improved from 0.00688 to 0.00646, saving model to model\dangjin_wind_checkpoint.h5
# Epoch 7/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0062 - val_loss: 0.0066
#
# Epoch 00007: val_loss did not improve from 0.00646
# Epoch 8/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0061
#
# Epoch 00008: val_loss improved from 0.00646 to 0.00612, saving model to model\dangjin_wind_checkpoint.h5
# Epoch 9/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0059 - val_loss: 0.0063
#
# Epoch 00009: val_loss did not improve from 0.00612
# Epoch 10/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0059 - val_loss: 0.0056
#
# Epoch 00010: val_loss improved from 0.00612 to 0.00563, saving model to model\dangjin_wind_checkpoint.h5
# Epoch 11/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0056 - val_loss: 0.0061
#
# Epoch 00011: val_loss did not improve from 0.00563
# Epoch 12/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0055 - val_loss: 0.0063
#
# Epoch 00012: val_loss did not improve from 0.00563
# Epoch 13/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0058 - val_loss: 0.0058
#
# Epoch 00013: val_loss did not improve from 0.00563
# Epoch 14/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0053 - val_loss: 0.0055
#
# Epoch 00014: val_loss improved from 0.00563 to 0.00552, saving model to model\dangjin_wind_checkpoint.h5
# Epoch 15/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0054 - val_loss: 0.0054
#
# Epoch 00015: val_loss improved from 0.00552 to 0.00542, saving model to model\dangjin_wind_checkpoint.h5
# Epoch 16/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0053 - val_loss: 0.0056
#
# Epoch 00016: val_loss did not improve from 0.00542
# Epoch 17/100
# 526/526 [==============================] - 3s 5ms/step - loss: 0.0055 - val_loss: 0.0053
#
# Epoch 00017: val_loss improved from 0.00542 to 0.00529, saving model to model\dangjin_wind_checkpoint.h5
# Epoch 18/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0057 - val_loss: 0.0056
#
# Epoch 00018: val_loss did not improve from 0.00529
# Epoch 19/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0055 - val_loss: 0.0058
#
# Epoch 00019: val_loss did not improve from 0.00529
# Epoch 20/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0056 - val_loss: 0.0053
#
# Epoch 00020: val_loss did not improve from 0.00529
# Epoch 21/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0054 - val_loss: 0.0051
#
# Epoch 00021: val_loss improved from 0.00529 to 0.00513, saving model to model\dangjin_wind_checkpoint.h5
# Epoch 22/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0054 - val_loss: 0.0053
#
# Epoch 00022: val_loss did not improve from 0.00513
# Epoch 23/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0052 - val_loss: 0.0053
#
# Epoch 00023: val_loss did not improve from 0.00513
# Epoch 24/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0054 - val_loss: 0.0053
#
# Epoch 00024: val_loss did not improve from 0.00513
# Epoch 25/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0056 - val_loss: 0.0054
#
# Epoch 00025: val_loss did not improve from 0.00513
# Epoch 26/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0050 - val_loss: 0.0054
#
# Epoch 00026: val_loss did not improve from 0.00513
# Epoch 27/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0052 - val_loss: 0.0054
#
# Epoch 00027: val_loss did not improve from 0.00513
# Epoch 28/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0053 - val_loss: 0.0057
#
# Epoch 00028: val_loss did not improve from 0.00513
# Epoch 29/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0052 - val_loss: 0.0052
#
# Epoch 00029: val_loss did not improve from 0.00513
# Epoch 30/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0052 - val_loss: 0.0053
#
# Epoch 00030: val_loss did not improve from 0.00513
# Epoch 31/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0050 - val_loss: 0.0053
#
# Epoch 00031: val_loss did not improve from 0.00513

# %%
dangjin_pred = model_2.predict(pred_feature)

# %%
df = energy_ulsan.copy()
df.head(24)
# Out:
#                    time  ulsan  capacity  time_generation  Temperature  \
# 0   2018-03-02 00:00:00    0.0     500.0            0.000     0.000000
# 1   2018-03-02 01:00:00    0.0     500.0            0.000    -0.333333
# 2   2018-03-02 02:00:00    0.0     500.0            0.000    -0.666667
# 3   2018-03-02 03:00:00    0.0     500.0            0.000    -1.000000
# 4   2018-03-02 04:00:00    0.0     500.0            0.000    -1.333333
# 5   2018-03-02 05:00:00    0.0     500.0            0.000    -1.666667
# 6   2018-03-02 06:00:00    0.0     500.0            0.000    -2.000000
# 7   2018-03-02 07:00:00    0.0     500.0            0.000    -1.333333
# 8   2018-03-02 08:00:00   18.0     500.0            0.036    -0.666667
# 9   2018-03-02 09:00:00  102.0     500.0            0.204     0.000000
# 10  2018-03-02 10:00:00  218.0     500.0            0.436     2.000000
# 11  2018-03-02 11:00:00  264.0     500.0            0.528     4.000000
# 12  2018-03-02 12:00:00  278.0     500.0            0.556     6.000000
# 13  2018-03-02 13:00:00  362.0     500.0            0.724     7.000000
# 14  2018-03-02 14:00:00  352.0     500.0            0.704     8.000000
# 15  2018-03-02 15:00:00  319.0     500.0            0.638     9.000000
# 16  2018-03-02 16:00:00  263.0     500.0            0.526     8.666667
# 17  2018-03-02 17:00:00  163.0     500.0            0.326     8.333333
# 18  2018-03-02 18:00:00   30.0     500.0            0.060     8.000000
# 19  2018-03-02 19:00:00    0.0     500.0            0.000     7.333333
# 20  2018-03-02 20:00:00    0.0     500.0            0.000     6.666667
# 21  2018-03-02 21:00:00    0.0     500.0            0.000     6.000000
# 22  2018-03-02 22:00:00    0.0     500.0            0.000     5.666667
# 23  2018-03-02 23:00:00    0.0     500.0            0.000     5.333333
#
#      Humidity     Cloud    Wind_X    Wind_Y
# 0   40.000000  2.000000  1.114717 -1.003696
# 1   41.666667  2.000000  1.124770 -1.137934
# 2   43.333333  2.000000  1.122746 -1.276496
# 3   45.000000  2.000000  1.108191 -1.418419
# 4   45.000000  1.666667  0.970799 -1.476028
# 5   45.000000  1.333333  0.831503 -1.520871
# 6   45.000000  1.000000  0.691452 -1.553027
# 7   41.666667  1.000000  0.962196 -1.481651
# 8   38.333333  1.000000  1.226739 -1.362432
# 9   35.000000  1.000000  1.476577 -1.195709
# 10  33.333333  1.000000  1.365885 -1.067147
# 11  31.666667  1.000000  1.251196 -0.942844
# 12  30.000000  1.000000  1.132624 -0.822899
# 13  30.000000  1.000000 -0.781989 -0.910216
# 14  30.000000  1.000000 -0.702981  0.711209
# 15  30.000000  1.000000  0.612836  0.514230
# 16  35.000000  1.000000  0.450000  0.779423
# 17  40.000000  1.000000  0.173648  0.984808
# 18  45.000000  1.000000 -0.191013  1.083289
# 19  50.000000  1.000000 -1.274651  0.255472
# 20  55.000000  1.000000 -0.809626 -1.262737
# 21  60.000000  1.000000  0.999235 -1.375329
# 22  63.333333  1.000000  0.688750 -1.332525
# 23  66.666667  1.000000  0.416080 -1.231616

# %%
df.sort_index(ascending=False).reset_index(drop=True)

scaler = MinMaxScaler()
scale_cols = ['Temperature', 'Humidity', 'Wind_X', 'Wind_Y', 'Cloud']
df_scaled = scaler.fit_transform(df[scale_cols])
df_scaled = pd.DataFrame(df_scaled)
df_scaled['Generation'] = df['time_generation']
scale_cols.append('Generation')
df_scaled.columns = scale_cols

# %%
feature_cols = ['Temperature', 'Humidity', 'Wind_X', 'Wind_Y', 'Cloud']
label_cols = ['Generation']

window_size = 24
n = len(df_scaled)

train = df_scaled[:int(n*0.8)]
train.dropna(axis=0, inplace=True)
test = df_scaled[int(n*0.8):int(-(24*29))]
test.dropna(axis=0, inplace=True)
pred_input = df_scaled[int(-(24*29)):]
# Out:
# D:\Anaconda\envs\data_engeneering\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\Anaconda\envs\data_engeneering\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
train_feature, train_label = train[feature_cols], train[label_cols]
train_feature, train_label = make_dataset(train_feature, train_label, window_size)

x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=0.2)

test_feature, test_label = test[feature_cols], test[label_cols]
test_feature, test_label = make_dataset(test_feature, test_label, window_size)

pred_feature, pred_label = pred_input[feature_cols], pred_input[label_cols]
pred_feature, pred_label = make_dataset(pred_feature, pred_label, window_size)

x_train.shape, x_valid.shape, test_feature.shape, pred_feature.shape
# Out:
# ((16815, 24, 5), (4204, 24, 5), (4541, 24, 5), (672, 24, 5))

# %%
model_3 = Sequential()
model_3.add(LSTM(24, 
               input_shape=(train_feature.shape[1], train_feature.shape[2]), 
               activation='relu', 
               kernel_regularizer=tf.keras.regularizers.l2(0.001),
               return_sequences=False)
          )

model_3.add(Dense(1, activation='relu'))
model_3.compile(loss='mean_squared_error', optimizer='adam')
model_3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 24)                2880
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 2,905
# Trainable params: 2,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10)
checkpoint = ModelCheckpoint(filename[3], monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
history_3 = model_3.fit(x_train, y_train, epochs=epoch,
                                      validation_data=(x_valid, y_valid), 
                                      callbacks=[early_stop, checkpoint])
# Out:
# Epoch 1/100
# 526/526 [==============================] - 4s 6ms/step - loss: 0.0637 - val_loss: 0.0584
#
# Epoch 00001: val_loss improved from inf to 0.05841, saving model to model\ulsan_wind_checkpoint.h5
# Epoch 2/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0590 - val_loss: 0.0584
#
# Epoch 00002: val_loss improved from 0.05841 to 0.05841, saving model to model\ulsan_wind_checkpoint.h5
# Epoch 3/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0589 - val_loss: 0.0584
#
# Epoch 00003: val_loss did not improve from 0.05841
# Epoch 4/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0564 - val_loss: 0.0373
#
# Epoch 00004: val_loss improved from 0.05841 to 0.03731, saving model to model\ulsan_wind_checkpoint.h5
# Epoch 5/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0307 - val_loss: 0.0147
#
# Epoch 00005: val_loss improved from 0.03731 to 0.01474, saving model to model\ulsan_wind_checkpoint.h5
# Epoch 6/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0140 - val_loss: 0.0114
#
# Epoch 00006: val_loss improved from 0.01474 to 0.01141, saving model to model\ulsan_wind_checkpoint.h5
# Epoch 7/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0115 - val_loss: 0.0107
#
# Epoch 00007: val_loss improved from 0.01141 to 0.01069, saving model to model\ulsan_wind_checkpoint.h5
# Epoch 8/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0112 - val_loss: 0.0112
#
# Epoch 00008: val_loss did not improve from 0.01069
# Epoch 9/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0108 - val_loss: 0.0106
#
# Epoch 00009: val_loss improved from 0.01069 to 0.01057, saving model to model\ulsan_wind_checkpoint.h5
# Epoch 10/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0108 - val_loss: 0.0101
#
# Epoch 00010: val_loss improved from 0.01057 to 0.01015, saving model to model\ulsan_wind_checkpoint.h5
# Epoch 11/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0099 - val_loss: 0.0098
#
# Epoch 00011: val_loss improved from 0.01015 to 0.00984, saving model to model\ulsan_wind_checkpoint.h5
# Epoch 12/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0098 - val_loss: 0.0108
#
# Epoch 00012: val_loss did not improve from 0.00984
# Epoch 13/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0100 - val_loss: 0.0097
#
# Epoch 00013: val_loss improved from 0.00984 to 0.00968, saving model to model\ulsan_wind_checkpoint.h5
# Epoch 14/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0096 - val_loss: 0.0099
#
# Epoch 00014: val_loss did not improve from 0.00968
# Epoch 15/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0097 - val_loss: 0.0103
#
# Epoch 00015: val_loss did not improve from 0.00968
# Epoch 16/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0100 - val_loss: 0.0100
#
# Epoch 00016: val_loss did not improve from 0.00968
# Epoch 17/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0102 - val_loss: 0.0101
#
# Epoch 00017: val_loss did not improve from 0.00968
# Epoch 18/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0097 - val_loss: 0.0101
#
# Epoch 00018: val_loss did not improve from 0.00968
# Epoch 19/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0096 - val_loss: 0.0095
#
# Epoch 00019: val_loss improved from 0.00968 to 0.00949, saving model to model\ulsan_wind_checkpoint.h5
# Epoch 20/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0096 - val_loss: 0.0095
#
# Epoch 00020: val_loss improved from 0.00949 to 0.00949, saving model to model\ulsan_wind_checkpoint.h5
# Epoch 21/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0095 - val_loss: 0.0094
#
# Epoch 00021: val_loss improved from 0.00949 to 0.00938, saving model to model\ulsan_wind_checkpoint.h5
# Epoch 22/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0095 - val_loss: 0.0094
#
# Epoch 00022: val_loss improved from 0.00938 to 0.00935, saving model to model\ulsan_wind_checkpoint.h5
# Epoch 23/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0094 - val_loss: 0.0096
#
# Epoch 00023: val_loss did not improve from 0.00935
# Epoch 24/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0093 - val_loss: 0.0105
#
# Epoch 00024: val_loss did not improve from 0.00935
# Epoch 25/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0099 - val_loss: 0.0094
#
# Epoch 00025: val_loss did not improve from 0.00935
# Epoch 26/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0098 - val_loss: 0.0094
#
# Epoch 00026: val_loss did not improve from 0.00935
# Epoch 27/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0093 - val_loss: 0.0094
#
# Epoch 00027: val_loss did not improve from 0.00935
# Epoch 28/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0095 - val_loss: 0.0093
#
# Epoch 00028: val_loss improved from 0.00935 to 0.00931, saving model to model\ulsan_wind_checkpoint.h5
# Epoch 29/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0092 - val_loss: 0.0098
#
# Epoch 00029: val_loss did not improve from 0.00931
# Epoch 30/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0096 - val_loss: 0.0093
#
# Epoch 00030: val_loss did not improve from 0.00931
# Epoch 31/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0092 - val_loss: 0.0097
#
# Epoch 00031: val_loss did not improve from 0.00931
# Epoch 32/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0092 - val_loss: 0.0106
#
# Epoch 00032: val_loss did not improve from 0.00931
# Epoch 33/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0094 - val_loss: 0.0098
#
# Epoch 00033: val_loss did not improve from 0.00931
# Epoch 34/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0092 - val_loss: 0.0095
#
# Epoch 00034: val_loss did not improve from 0.00931
# Epoch 35/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0095 - val_loss: 0.0094
#
# Epoch 00035: val_loss did not improve from 0.00931
# Epoch 36/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0094 - val_loss: 0.0094
#
# Epoch 00036: val_loss did not improve from 0.00931
# Epoch 37/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0095 - val_loss: 0.0093
#
# Epoch 00037: val_loss did not improve from 0.00931
# Epoch 38/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0092 - val_loss: 0.0092
#
# Epoch 00038: val_loss improved from 0.00931 to 0.00919, saving model to model\ulsan_wind_checkpoint.h5
# Epoch 39/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0094 - val_loss: 0.0105
#
# Epoch 00039: val_loss did not improve from 0.00919
# Epoch 40/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0092 - val_loss: 0.0093
#
# Epoch 00040: val_loss did not improve from 0.00919
# Epoch 41/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0092 - val_loss: 0.0094
#
# Epoch 00041: val_loss did not improve from 0.00919
# Epoch 42/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0093 - val_loss: 0.0091
#
# Epoch 00042: val_loss improved from 0.00919 to 0.00912, saving model to model\ulsan_wind_checkpoint.h5
# Epoch 43/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0090 - val_loss: 0.0092
#
# Epoch 00043: val_loss did not improve from 0.00912
# Epoch 44/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0092 - val_loss: 0.0091
#
# Epoch 00044: val_loss did not improve from 0.00912
# Epoch 45/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0091 - val_loss: 0.0090
#
# Epoch 00045: val_loss improved from 0.00912 to 0.00902, saving model to model\ulsan_wind_checkpoint.h5
# Epoch 46/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0092 - val_loss: 0.0092
#
# Epoch 00046: val_loss did not improve from 0.00902
# Epoch 47/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0086 - val_loss: 0.0093
#
# Epoch 00047: val_loss did not improve from 0.00902
# Epoch 48/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0088 - val_loss: 0.0090
#
# Epoch 00048: val_loss improved from 0.00902 to 0.00901, saving model to model\ulsan_wind_checkpoint.h5
# Epoch 49/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0089 - val_loss: 0.0089
#
# Epoch 00049: val_loss improved from 0.00901 to 0.00895, saving model to model\ulsan_wind_checkpoint.h5
# Epoch 50/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0090 - val_loss: 0.0092
#
# Epoch 00050: val_loss did not improve from 0.00895
# Epoch 51/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0090 - val_loss: 0.0093
#
# Epoch 00051: val_loss did not improve from 0.00895
# Epoch 52/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0088 - val_loss: 0.0089
#
# Epoch 00052: val_loss improved from 0.00895 to 0.00891, saving model to model\ulsan_wind_checkpoint.h5
# Epoch 53/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0092 - val_loss: 0.0090
#
# Epoch 00053: val_loss did not improve from 0.00891
# Epoch 54/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0091 - val_loss: 0.0093
#
# Epoch 00054: val_loss did not improve from 0.00891
# Epoch 55/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0089 - val_loss: 0.0091
#
# Epoch 00055: val_loss did not improve from 0.00891
# Epoch 56/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0089 - val_loss: 0.0089
#
# Epoch 00056: val_loss did not improve from 0.00891
# Epoch 57/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0087 - val_loss: 0.0092
#
# Epoch 00057: val_loss did not improve from 0.00891
# Epoch 58/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0092 - val_loss: 0.0091
#
# Epoch 00058: val_loss did not improve from 0.00891
# Epoch 59/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0088 - val_loss: 0.0091
#
# Epoch 00059: val_loss did not improve from 0.00891
# Epoch 60/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0089 - val_loss: 0.0090
#
# Epoch 00060: val_loss did not improve from 0.00891
# Epoch 61/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0090 - val_loss: 0.0089
#
# Epoch 00061: val_loss did not improve from 0.00891
# Epoch 62/100
# 526/526 [==============================] - 3s 6ms/step - loss: 0.0091 - val_loss: 0.0093
#
# Epoch 00062: val_loss did not improve from 0.00891

# %%
ulsan_pred = model_3.predict(pred_feature)

# %%
model_3.load_weights(filename[3])
pred = model_3.predict(test_feature)

# %%
day = 50
day_range = 10

plt.figure(figsize=(20, 5))
plt.title('Ulsan', fontsize=20)
plt.plot(test_label[-day*24:-(day-day_range)*24], label = 'actual')
plt.plot(pred[-day*24:-(day-day_range)*24], label = 'prediction')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.plot(floating_pred * energy_floating.loc[0, 'capacity'], label = 'dangjin_floating_pred')
plt.plot(warehouse_pred * energy_warehouse.loc[0, 'capacity'], label = 'dangjin_warehouse_pred')
plt.plot(dangjin_pred * energy_dangjin.loc[0, 'capacity'], label = 'dangjin_pred')
plt.plot(ulsan_pred * energy_ulsan.loc[0, 'capacity'], label = 'ulsan_pred')
plt.legend()
plt.show()

# %%
submission = pd.read_csv('data/sample_submission.csv')

# %%
submission.iloc[:24*28, 1] = floating_pred * energy_floating.loc[0, 'capacity']
submission.iloc[:24*28, 2] = warehouse_pred * energy_warehouse.loc[0, 'capacity']
submission.iloc[:24*28, 3] = dangjin_pred * energy_dangjin.loc[0, 'capacity']
submission.iloc[:24*28, 4] = ulsan_pred * energy_ulsan.loc[0, 'capacity']

# %%
submission.to_csv('submission.csv', index=False)
submission.head(48)
# Out:
#                    time  dangjin_floating  dangjin_warehouse     dangjin  \
# 0   2021-02-01 01:00:00          0.000000           0.000000    0.000000
# 1   2021-02-01 02:00:00          0.000000           0.000000    0.000000
# 2   2021-02-01 03:00:00          0.000000           0.000000    0.000000
# 3   2021-02-01 04:00:00          0.000000           0.000000    0.000000
# 4   2021-02-01 05:00:00          0.000000           0.000000    0.000000
# 5   2021-02-01 06:00:00          0.000000           0.000000    0.000000
# 6   2021-02-01 07:00:00          0.000000           0.000000    2.504610
# 7   2021-02-01 08:00:00         26.493910           0.000000   49.103165
# 8   2021-02-01 09:00:00         89.515594          22.210621   97.877464
# 9   2021-02-01 10:00:00        174.841309         115.691795  138.474731
# 10  2021-02-01 11:00:00        273.389404         223.430557  303.363342
# 11  2021-02-01 12:00:00        378.097565         266.396912  448.368164
# 12  2021-02-01 13:00:00        477.094910         293.135956  551.085205
# 13  2021-02-01 14:00:00        510.619507         300.042969  605.319458
# 14  2021-02-01 15:00:00        464.565979         260.789459  567.786011
# 15  2021-02-01 16:00:00        373.633636         222.340958  444.859070
# 16  2021-02-01 17:00:00        260.235565         186.023621  297.087646
# 17  2021-02-01 18:00:00        167.849030         146.866394  132.713882
# 18  2021-02-01 19:00:00        118.299873         124.264603   17.785273
# 19  2021-02-01 20:00:00         83.701042          92.580841    0.000000
# 20  2021-02-01 21:00:00         43.921474          19.209093    0.000000
# 21  2021-02-01 22:00:00          0.000000           0.000000    0.000000
# 22  2021-02-01 23:00:00          0.000000           0.000000    0.000000
# 23  2021-02-01 24:00:00          0.000000           0.000000    0.000000
# 24  2021-02-02 01:00:00          0.000000           0.000000    0.000000
# 25  2021-02-02 02:00:00          0.000000           0.000000    0.000000
# 26  2021-02-02 03:00:00          0.000000           0.000000    0.000000
# 27  2021-02-02 04:00:00          0.000000           0.000000    0.000000
# 28  2021-02-02 05:00:00          0.000000           0.000000    0.000000
# 29  2021-02-02 06:00:00          0.000000           0.000000    0.000000
# 30  2021-02-02 07:00:00          0.000000           0.000000    0.000000
# 31  2021-02-02 08:00:00          0.000000           0.000000    0.000000
# 32  2021-02-02 09:00:00          0.000000           8.202457   13.656221
# 33  2021-02-02 10:00:00         28.027092           0.000000   39.799831
# 34  2021-02-02 11:00:00         96.800896          12.679884  214.305252
# 35  2021-02-02 12:00:00        211.183044         138.612854  396.590393
# 36  2021-02-02 13:00:00        375.953552         270.648621  503.354614
# 37  2021-02-02 14:00:00        495.175354         339.212250  567.110840
# 38  2021-02-02 15:00:00        460.184418         313.512085  527.447876
# 39  2021-02-02 16:00:00        355.875549         248.274475  393.999023
# 40  2021-02-02 17:00:00        246.135834         185.480804  278.032288
# 41  2021-02-02 18:00:00        111.120522          79.720062  159.595932
# 42  2021-02-02 19:00:00          0.000000           0.000000    0.000000
# 43  2021-02-02 20:00:00          0.000000           0.000000    0.000000
# 44  2021-02-02 21:00:00          0.000000           0.000000    0.000000
# 45  2021-02-02 22:00:00          0.000000           0.000000    0.000000
# 46  2021-02-02 23:00:00          0.000000           0.000000    0.000000
# 47  2021-02-02 24:00:00          0.000000           0.000000    0.000000
#
#          ulsan
# 0    10.577107
# 1    25.342684
# 2    21.946039
# 3     9.377892
# 4     0.973309
# 5     0.000000
# 6     0.242303
# 7     8.706848
# 8    24.321478
# 9    50.594414
# 10   81.817459
# 11  129.939423
# 12  177.296906
# 13  218.633057
# 14  232.544464
# 15  231.027100
# 16  226.344757
# 17  215.811707
# 18  201.927368
# 19  180.114395
# 20  131.393173
# 21   61.606209
# 22   10.982464
# 23    0.000000
# 24    0.000000
# 25    0.000000
# 26    0.000000
# 27    0.000000
# 28    0.000000
# 29    0.000000
# 30    0.000000
# 31    0.000000
# 32   25.466482
# 33  100.813545
# 34  154.885330
# 35  202.039841
# 36  243.596039
# 37  284.494568
# 38  289.561798
# 39  259.826569
# 40  202.058304
# 41  120.718369
# 42   38.929413
# 43    0.000000
# 44    0.000000
# 45    0.000000
# 46    0.000000
# 47    0.000000

# %%
initializer = HeNormal()
regularizer = l2(0.001)

epoch = 200
patience_count = 20
model_0 = Sequential()
model_0.add(LSTM(48, 
               input_shape=(train_feature.shape[1], train_feature.shape[2]), 
               activation='relu', 
               kernel_initializer=initializer,
               kernel_regularizer=regularizer,
               return_sequences=True)
          )
model_0.add(Dropout(0.6))
model_0.add(LSTM(24, 
               input_shape=(train_feature.shape[1], train_feature.shape[2]), 
               activation='relu', 
               kernel_initializer=initializer,
               kernel_regularizer=regularizer,
               return_sequences=False)
          )
model_0.add(Dropout(0.6))
model_0.add(Dense(24, activation='relu'))
model_0.add(Dense(1))
model_0.compile(loss='mean_squared_error', optimizer='adam')
model_0.summary()
