# %%
import pandas as pd

# %%
df = pd.read_csv('data/energy_dangjin_sunlight.csv')              # 발전소 정보

# %%
df
# Out:
#                       time  dangjin  capacity  time_generation  Temperature  \
# 0      2018-03-02 00:00:00      0.0    1000.0              0.0    -2.000000
# 1      2018-03-02 01:00:00      0.0    1000.0              0.0    -2.666667
# 2      2018-03-02 02:00:00      0.0    1000.0              0.0    -3.333333
# 3      2018-03-02 03:00:00      0.0    1000.0              0.0    -4.000000
# 4      2018-03-02 04:00:00      0.0    1000.0              0.0    -4.333333
# ...                    ...      ...       ...              ...          ...
# 26299  2021-03-01 19:00:00      NaN       NaN              NaN     6.333333
# 26300  2021-03-01 20:00:00      NaN       NaN              NaN     5.666667
# 26301  2021-03-01 21:00:00      NaN       NaN              NaN     5.000000
# 26302  2021-03-01 22:00:00      NaN       NaN              NaN     5.000000
# 26303  2021-03-01 23:00:00      NaN       NaN              NaN     5.000000
#
# ...

# %%
temp_df = df.drop(['capacity', 'time_generation'], axis=1)

# %%
temp_df.rename(columns={'time':'date'}, inplace=True)

# %%
temp_df
# Out:
#                       date  dangjin  Temperature   Humidity  WindSpeed  \
# 0      2018-03-02 00:00:00      0.0    -2.000000  55.000000        6.7
# 1      2018-03-02 01:00:00      0.0    -2.666667  55.000000        6.3
# 2      2018-03-02 02:00:00      0.0    -3.333333  55.000000        5.9
# 3      2018-03-02 03:00:00      0.0    -4.000000  55.000000        5.5
# 4      2018-03-02 04:00:00      0.0    -4.333333  56.666667        5.1
# ...                    ...      ...          ...        ...        ...
# 26299  2021-03-01 19:00:00      NaN     6.333333  85.000000        6.3
# 26300  2021-03-01 20:00:00      NaN     5.666667  85.000000        6.1
# 26301  2021-03-01 21:00:00      NaN     5.000000  85.000000        5.9
# 26302  2021-03-01 22:00:00      NaN     5.000000  85.000000        5.9
# 26303  2021-03-01 23:00:00      NaN     5.000000  85.000000        5.9
#
#        WindDirection  Cloud  일조(hr)  일사(MJ/m2)
# 0         336.000000    1.0     0.0        0.0
# ...

# %%
temp_df.to_csv('data/ex1.csv', index=False)
